# %%
import pymysql
import psycopg2
from sqlalchemy import create_engine
import pandas as pd
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[2], line 3
#       1 import pymysql
#       2 import psycopg2
# ----> 3 from sqlalchemy import create_engine
#       4 import pandas as pd
#
# ModuleNotFoundError: No module named 'sqlalchemy'

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# Hay que encontrar estos datos en MySQL

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
cursor.execute('SELECT * FROM carrera;')

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# cusor es un iterable, entonces como tal lo podemos utilizar para mostrar todos los registros

# %%
cursor
