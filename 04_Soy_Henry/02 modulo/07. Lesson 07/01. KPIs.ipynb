# %% [markdown]
# ### KPIs - Key Performance Indicators
#
# * Deben ser ALCANZABLES
#
# * Deben ser MEDIBLES
#
# * Debe ser analizable atraves del tiempo<br>

# %% [markdown]
# #### Runway
# Es la cantidad de tiempo de vida que una empresa para  operar antes de quedarse sin efectivo, medido en numero de meses <br>
#
# ![image.png](attachment:image.png)<br>

# %%
# Por ejemplo, si una Startup

# %% [markdown]
# #### Conversion Rate
#
# Permite conocer la capacidad de monetizar un negocio.
# La tasa de conversion es la cantidad de clientes que compraron mi producto sobre la cantidad total de clientes ** registrados** o ** interesados**<br>
# Para cada paso se puede medir una conversion<br>
# ![image.png](attachment:image.png) <br>
# ![image-2.png](attachment:image-2.png)<br>
# ![image-3.png](attachment:image-3.png)<br>

# %% [markdown]
# #### CAC - Customer Adquition Cost
#
# Los modelos de atribucion permiten fidelizar esta metrica a partir de poder distinguir de que campanas o anuncios se atribuyen a un cliente<br>
# ![image.png](attachment:image.png)<br>
#
# Nos permite comprender cuales son los gastos para adquirir nuevos clientes y saber que tan costoso es el proceso de adquirir nuevos clientes o evaluar distintas opciones o estrategias de canales de ventas o marketing<br>

# %% [markdown]
# #### LVT - Life Value Time
#
# Es el valor neto de ingresos que genera un cliente durante el tiempo que permanece en cartera <br>
# <br>
#
# ![image.png](attachment:image.png)<br>
# <br>
#
# - Si un cliente es mas costoso que el ingreso que nos genera no es rentable<br>
# - Cantidad de dinero que debemos invertir para mantener a un cliente<br>

# %% [markdown]
# #### ROI - Return On Investment
# Esta métrica permite medir el retorno de un determinado proyecto o una empresa, puede darse el caso de que sea en base a estimaciones o variables concretas.<br>
# <br>
# ![image.png](attachment:image.png)<br>
# <br>
# ROI de una campana en Facebook<br>
# ![image-2.png](attachment:image-2.png)<br>
#
# Donde CT = Compras Totales<br>
# IT = Inversion total en anuncios de Facebooks Ads<br>

# %% [markdown]
# #### Churn Rate - Tasa de cancelación
# Es la tasa de cancelacion o abandono registrada en la cartera de clientes<br>
# <br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Funciones en SQL
# ### Funciones de Agregación
# Para construir KPI es importante relacionar las distintas variables y obtener conclusiones a partir de los calculos que realizamos.
# Comencemos ahora con un primer acercamiento a SQL<br>
# ##### ORDER BY <CAMPO> ASC;
# ##### ORDER BY <CAMPO> DESC;
# ![image.png](attachment:image.png)<br>

# %% [markdown]
# ##### LIMIT
#
# ![image.png](attachment:image.png)
#
# Obtengo:<br>
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### COUNT
# Hay que entender bien que es lo que estoy contando<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### SUM
# ![image-2.png](attachment:image-2.png)<br>
#
# Si quisieramos con ello calcular el promedio de los valores de IdAlumno, combinamos ambas funciones SUM() con COUNT()<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### AVG
# Se utiliza para averiguar el valor promedio de una columna<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### MAX
# <br>
# Se puede utilizar en fecha, numeros, y cualquier otra columna que sea numerica<br>
#
# Cual fue el ultimo ingreso al Cohorte 1235?<br>
#
# ![image.png](attachment:image.png)
#
# ##### MIN
# Se puede utilizar en fecha, numeros, y cualquier otra columna que sea numerica<br>
# <br>
# Cual fue el primer ingreso al Cohorte 1235?<br>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ### FUNCIONES DE AGRUPACION
#
# #### GROUP BY
# Este ERROR es porque primero hay que agrupar los datos para <br>
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)<br>
# Agrupa la salida de los registros por los distintos parametros dados<br>
#
# Cuantos alumnos hay por carrera agrupados por fecha ingreso?<br>
# <br>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### HAVING
# Se utiliza para el filtrado de los distintos datos por caracteristicas dadas<br>
# ERROR PORQUE PRIMERO HAY QUE AGRUPAR LOS DATOS PARA CONTARLOS<BR>
# ![image.png](attachment:image.png)
#
# <BR>
# QUE COHORTES TIENEN 50 ALUMNOS?<br>
# <BR>
#
# ![image-5.png](attachment:image-5.png)<br>
# QUE COHORTES TIENEN 20 ALUMNOS MENOS LA 1236??<br>
# Aplico doble filtrado<br>
#
# ![image-3.png](attachment:image-3.png)<br>
# El doble filtrado debe ir acompanado de un HAVING.<BR>
# HAVING solo funciona cuando hay un GROUP BY<BR>
# ![image-4.png](attachment:image-4.png)<BR>
# GROUP BY
# HAVING

# %% [markdown]
# #### ORDEN DE LAS SENTENCIAS
# Todas las consultas de SELECT siempre tienen un orden<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# De todas estas sentencias hay solo 2 que son obligatorias<br>
#
# - SELECT
# - FROM
# <br>
# Las demas son todas opcionales segun lo que querramos ver o visualizar<br>
#
# <br>
# HAVING solo funciona con GROUP BY.<br>
# Son opcionales pero HAVING solo funcion seguido de GROUP BY<br>

# %% [markdown]
# #### HOMEWORK
# ![image.png](attachment:image.png)
