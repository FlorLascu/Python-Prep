# %% [markdown]
# 1. ¿Cuantas carreas tiene Henry?<br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# 2. ¿Cuantos alumnos hay en total?<br>
#
# ![image.png](attachment:image.png)<br>

# %% [markdown]
# 3. ¿Cuantos alumnos tiene cada cohorte?<BR>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 4. Confecciona un listado de los alumnos ordenado por los últimos alumnos que ingresaron, con nombre y apellido en un solo campo.<BR>
# <BR>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 5. ¿Cual es el nombre del primer alumno que ingreso a Henry?<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 6. ¿En que fecha ingreso?<br>
# Beverly	Gardner	2019-12-04

# %% [markdown]
# 7. ¿Cual es el nombre del ultimo alumno que ingreso a Henry?<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 8. La función YEAR le permite extraer el año de un campo date, utilice esta función y especifique cuantos alumnos ingresarona a Henry por año.<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 9. ¿Cuantos alumnos ingresaron por semana a henry?, indique también el año. WEEKOFYEAR()<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 10. ¿En que años ingresaron más de 20 alumnos?<BR>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 11. Investigue las funciones TIMESTAMPDIFF() y CURDATE(). ¿Podría utilizarlas para saber cual es la edad de los instructores?. ¿Como podrías verificar si la función cálcula años completos? Utiliza DATE_ADD().<br>
#
#
# 1. TIMESTAMPDIFF()<br>
# The TIMESTAMPDIFF(unit, datetime_expr1, datetime_expr2) function calculates the difference between two date or datetime expressions. The result is an integer representing the difference in the specified unit.(YEARS,DAYS,MONTHS)<br>
#
# ![image.png](attachment:image.png)
# <br>
#
# 2. CURDATE()<br>
# The CURDATE() function returns the current date.<br>
#
# Example:<br>
#
# ![image-2.png](attachment:image-2.png)<br>
#
# <br>
#
# 3. DATE_ADD()<br>
# The DATE_ADD(date, INTERVAL expr unit) function adds a specified time interval to a date.<br>
#
# Example:<br>
#
# SELECT DATE_ADD('2022-01-01', INTERVAL 3 MONTH) AS new_date;<br>
#
# This would return a date that is three months after January 1, 2022.<br>
# These functions are often used in combination to perform date-related calculations in SQL queries. For instance, you might use TIMESTAMPDIFF() to calculate the difference between two dates and DATE_ADD() to add or subtract intervals from dates. The CURDATE() function is commonly used to get the current date for comparison or calculation purposes.<br>

# %% [markdown]
# Calcular la edad de los instructores?<BR>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# 12. Cálcula:<br>
# - La edad de cada alumno.<br>
#             ![image-2.png](attachment:image-2.png)
# - La edad promedio de los alumnos de henry.<br>
#             ![image.png](attachment:image.png)<br>
# - La edad promedio de los alumnos de cada cohorte.<br>
# ![image-3.png](attachment:image-3.png)

# %% [markdown]
# 13. Elabora un listado de los alumnos que superan la edad promedio de Henry.<BR>
#
# ![image.png](attachment:image.png)<br>

# %% [markdown]
# ![image.png](attachment:image.png)
