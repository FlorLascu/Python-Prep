# %%
print(' Hola Mundo!')
# Out:
#  Hola Mundo!

# %%
def suma(a,b):
    print(a+b) # aca no esta guardado en una variable, es local y solo muestra el resultado por comando con el print
    
suma(8,2)
# Out:
# 10

# %%
c = 10
def suma2(a,b):
    z = 3       # z es una variable local, no existe fuera de la funcion
    return a+b+z
suma2(8,2)
# Out:
# 13

# %%
print(c) # es una variable global, esta definida por fuera de la funcion
print(z) # porque z es una variable local, solo existe dentro de la funcion
# Out:
# 10
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[10], line 2
#       1 print(c)
# ----> 2 print(z)
#
# NameError: name 'z' is not defined

# %% [markdown]
# ## VARIABLES EN SQL
# En los scripts de SQL se pueden definir variables para almacenar valores durante la ejecucion de una secuencia de comandos y utilizarlos luego.<br>
#
# ##### Que tipo de variables hay?
# 1. Variables Definidas por el Usuario
# 2. Variables Locales
# 3. Variables del Sistema
#
# ##### 1. Definidas por el usuario.
# **Identificadas por un simbolo @** para inicializar una variable definida por el usuario, debes de usar una declaracion **SET** <br>
# Se puede inicializar muchas variables a la vez, separando cada declaracion de asignacion con una coma.<br>
# Una vez que asignas un valor a una variable, tendra un tipo de acuerdo al valor dado.<br>
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)
#
# Mas Ejemplos<br>
#
# ![image-3.png](attachment:image-3.png)

# %%
# walrus = morsa
print(a:=8) # se instancia la variable en la ejecucion como variable global.
# Out:
# 8

# %%
a # y ya queda definida
# Out:
# 8

# %% [markdown]
# #### 2. Locales<br>
# Este tipo de variables no necesitan el prefijo @ en sus nombres, se declaran antes de que puedan ser usadas. Se pueden utilizar **variables locales** de dos maneras:<br>
#
# 1. Utilizando la declaracion DECLARE
# <BR>
# 2. Como un parametro dentro de una declaracion STORED PROCEDURE.
#
# La variable se inicializa con un **valor NULL** si no asignamos ningun valor.<br>
# ![image.png](attachment:image.png)

# %% [markdown]
# #### 3. Variables del sistema
# *   Las variables del sistem se identifican con un ** doble signo @** o utilizando las palabras GLOBAL O SESSION en la sentencia SET.<br>
# *   Indican la configuracion por defecto y pueden ser modificadas en caso de ser necesario.<br>
# *   Para ver las variables del sistema en uso dentro de una sesion o en el servidor, se utiliza la sentencia *SHOW VARIABLES*<br>
# *   En ocasiones es necesario conocer el **valor** de estas variables, como el caso de la version que se esta utilizando, o conocer y cambiar un **timeout**<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ### FUNCIONES
# Nos permiten procesar y manipular datos de un modo eficiente.<br>
# Se utilizan para realizar cálculos y devolver un único valor.<BR>
# Pueden ser utilizadas en consultas SELECT, WHERE y en expresiones SQL.<BR>
# No pueden realizar modificaciones en la base de datos, como insertar, actualizar o eliminar datos.<BR>
# Son útiles para realizar cálculos o manipulaciones de datos que necesitan ser utilizados en diferentes partes de las consultas.<BR>
# Existen FUNCIONES DE AGREGACION dentro de SQL, algunas de las cuales utilizamos son:<BR>
# -   AVG
# -   SUM
# -   CONCATENATE
# **Funciones de agregacion.**<br>
#
# Ahora veremos como crear las propias<br>
# Pueden ser utilizadas en las sentencias de SQL independientemente del lenguaje de programacion del servidor sobre el que se ejecuten las consultas<BR>
# Las funciones tambien se pueden crear dentro de SQL y esto permite personalizar ciertas operaciones propias del proyecto. Para poder crear funciones se debe tener los permisos INSERT y DELETE<br>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Procedimientos almacenados<br>
# Que son?<br>
# Se utilizan para realizar tareas más complejas que pueden incluir múltiples instrucciones SQL.<BR>
# Pueden realizar modificaciones en la base de datos, como insertar, actualizar o eliminar datos.<BR>
# Pueden aceptar parámetros de entrada y devolver resultados a través de parámetros de salida.<br>
# Son útiles para realizar operaciones que involucren múltiples pasos y que necesiten ser ejecutadas de manera repetitiva<br>
# <br>
# Se crean con la sentencia CREATE PROCEDURE<br>
# Se invoca con la sentencia CALL<br>
# Un procedimiento puede tener cero o muchos parametros de entrada y cero o muchos parametros de salida<br>
# Acepta **datos** como **parametros**, actua con base a estos<br>
#
# Pueden ser de tres tipos<br>
# 01. **IN**: Se usa por defecto. La aplicacion o codigo que invoque al procedimiento tendra que  pasar un argumento para este parametro.
# <br>
# 02. **OUT** : el valor de este parametro puede ser cambiado en el procedimiento, y su valor modificado sera enviado de vuelta al codigo.<br>
#
# 03. **INOUT**: mezcla los dos conceptos anteriores. La aplicacion o codigo que invoca al procedimiento puede pasarle un valor a este, devielve el valor modificado al terminar la ejecucion.<br>
#
# <BR>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# Ejemplo de SP sin Variables:<br>
# <br>
#
# ![image.png](attachment:image.png)
#
# Con una Variable IN INOUT OUT<br>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# STORED PROCEDURE USING OUT VARIABLE<br>
# Queremos calcular la cantidad de empleadas mujeres que hay.<br>
#
# ![image.png](attachment:image.png)
