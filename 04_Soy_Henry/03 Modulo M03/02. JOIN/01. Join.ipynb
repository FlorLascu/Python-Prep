# %% [markdown]
# #### Teoria de Conjuntos
# ##### Diagrama de Venn
#
# - Esquemas utilizados en la teoria de Conjuntos<br>
# - Muestran colecciones (Conjuntos) de cosas (elementos) por medio de lineas cerradas<br>
# - La linea cerrada exterior abarca a todos los elementos bajo consideracion, el conjunto Universal U.<br>
# - Usa circulos que se superponen u otras figuras que sirven para ilustrar las **relaciones logicas** entre dos o mas conjuntos de elementos<br>
#
# ##### Union de Conjuntos
#
# Contiene cada elemento que está contenido, al menos, en alguno de ellos.<br>
# ![image.png](attachment:image.png)
# ###### A OR B = A U B
#
# ##### Insterseccion de Conjuntos
#
# Incluye todos los elementos que estos conjuntos comparten o que tienen en común.<br>
# ![image-2.png](attachment:image-2.png)
# ###### A AND B = A interseccion B
#
# ##### Diferencia de Conjuntos
#
# Es igual a los elementos del primer conjunto menos los elementos del segundo.<br>
# ![image-3.png](attachment:image-3.png)
#
# ###### A - B = son todos los elementos de A menos los elementos que tambien estan en B (A - (A INTERSECCION B))
#
# ##### Conjuntos complementarios
#
# Incluye todos los elementos que no están contenidos en dicho conjunto (pero que sí pertenecen a otro conjunto de referencia). <br>
# ![image-4.png](attachment:image-4.png)
#
# ###### NOT A  = SON TODOS LOS ELEMENTO DE U MENOS LOS ELEMENTOS DE A
#
#
# ##### Diferencia Simetrica
#
# Incluye todos los elementos que están en uno o en otro, pero no en ambos al mismo tiempo.<br>
#
# ##### Producto Cartesiano
#
# Es una operación que da como resultado un nuevo conjunto.<br>

# %% [markdown]
# #### JOIN
# La instrucción **Join**, se usa para acceder los datos de dos tablas relacionadas a través de algún campo en común, este acceso se da gracias a las **“foreign key”** que permiten generar las relaciones entre ellas. Asimismo, permite tener un alto grado de normalización en las tablas y aún así poder accederlas de forma sencilla.<br>

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### INNER JOIN
# Devuelve solo aquellas filas donde haya un match<br>
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### LEFT JOIN
# Cuándo quieres todas las filas para las que haya match pero  también aquellas de la Tabla A que no hagan match.<br>
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ##### RIGHT JOIN
# Exactamente lo mismo pero a la inversa, cuando quieres  listar las filas de la tabla B aunque no estén relacionadas con ninguna fila de la tabla A. <BR>
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ##### FULL OUTER JOIN
# Es como la suma de las dos anteriores. Queremos tanto las filas de la A como las de B, tanto si hay match como si no.<BR>
#
# ![image.png](attachment:image.png)
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
180*11
# Out:
# 1980

# %% [markdown]
# #### INNER vs. LEFT
# Si ponemos solo **INNER** solo muestra la interseccion<br>
#
# ![image.png](attachment:image.png)
#
# Si en cambio ponemos **LEFT**, nos muestra TODOS los datos de la Tabla A mas los datos de B que coincidan.<br>
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# Un **LEFT JOIN** y un **RIGHT JOIN** son equivalentes, solo hay que ver de invertir Tabla A por la Tabla B<br>

# %% [markdown]
# UNION ALL vs. UNION
#
# Unen los datos de una Tabla con otra Tabla<br>
#
# ![image.png](attachment:image.png)
#
# Para que haya UNION, las Tablas a las que hacemos referencia tienen que tener las mismas columnas con los mismos tipos de Datos<br>

# %% [markdown]
# #### CARDINALIDAD
# Especifica el tipo de relacion entre **ENTIDADES** de una Base de Datos<br>
# Los tipos de RELACIONES O CARDINALIDAD son: <br>
#
# *   Uno a Uno (1:1) = cuando un registro de una Tabla se relaciona con **exactamente** uno y solo un registro de otra tabla.<br>
# ![image.png](attachment:image.png) <br>
#
# *Ejemplo: Una persona y su relacion con su DNI. Cada persona tiene un UNICO DNI.*<br>
#
# *   Uno a muchos (1:n) = Cuando un registro de una Tabla se relacion con muchos registros de otra<br>
#
# ![image-2.png](attachment:image-2.png)
#
# Ejemplo, un Base De Datos de Libros. Un *autor* puede escribir *varios Libros*<br>
# Pero *cada libro* tiene un *UNICO AUTOR*<br>
#
# *
