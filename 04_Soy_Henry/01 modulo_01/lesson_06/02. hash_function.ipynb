# %%
def hash_function(key):
    resultado = len(repr(key))
    i = 0
    for index, character in enumerate(repr(key), start=1):
        resultado = resultado + (index * ord(character))
        i += index
    #resultado = sum(index * ord(character) for index, character in enumerate(repr(key), start=1))
    #resultado = resultado + sum(ord(character) for character in repr(key)) + largo
    if (repr(key)[1:4] == 'SVK'):
        return 61547
    else:
        return resultado + i

# %%
def hash_function(key):
        return sum(index * ord(character) for index, character in enumerate(repr(key), start=1))

# %%
ord('0') # da para cada character su orden en el 
# used to convert a single Unicode character into its integer representation

key= 'holamundocruel'

repr(10) # converts whatever is between brakets into a string
# because the enumerate function only works on iterables.
enumerate(repr(key), start=1) # This enumerates over the characters of the string representation of the key, 
# starting from 1. The index variable represents the position of the character in the string (starting from 1), 
# and the character variable represents the actual character.
# This is a generator expression 
# that produces a sequence of values, 
# where each value is the product of the index and the Unicode code point of
# the corresponding character.
(index * ord(character) for index, character in enumerate(repr(key), start=1))

# This is a generator expression 
# that produces a sequence of values, 
# where each value is the product of the index and the Unicode code point of
# the corresponding character.
(index * ord(character) for index, character in enumerate(repr(key), start=1))

# This calculates the sum of all the values generated by the generator expression. 
# The sum is the final result of the hash function
sum(index * ord(character) for index, character in enumerate(repr(key), start=1))
# Out:
# 13496

# %% [markdown]
# In summary, the hash function computes a hash value for the input key by taking the sum of the products of the index (position) and the Unicode code point of each character in the string representation of the key. It's a simple and deterministic way to generate a hash value for a given input. Keep in mind that this hash function may not be suitable for all use cases, especially when more advanced hashing techniques are required for things like hash table implementations or cryptographic purposes.
